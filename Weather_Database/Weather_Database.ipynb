# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
# YOUR CODE HERE
cities = []
# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
# YOUR CODE HERE
len(cities)
# Out:
# 773

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=45b377d0e5071e0acb862c275ba0ec04

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        #time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        # YOUR CODE HERE  
        
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_description = city_weather["weather"][0]["description"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        
        # Append the city information into the city_data list
        # YOUR CODE HERE
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Current Description":city_description,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})
        
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | pevek
# Processing Record 2 of Set 1 | mataura
# Processing Record 3 of Set 1 | tomatlan
# Processing Record 4 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 5 of Set 1 | caravelas
# Processing Record 6 of Set 1 | punta arenas
# Processing Record 7 of Set 1 | kapaa
# Processing Record 8 of Set 1 | saint-philippe
# Processing Record 9 of Set 1 | kitui
# Processing Record 10 of Set 1 | klaksvik
# Processing Record 11 of Set 1 | nandurbar
# Processing Record 12 of Set 1 | albany
# Processing Record 13 of Set 1 | spasskoye
# Processing Record 14 of Set 1 | jamestown
# Processing Record 15 of Set 1 | leh
# Processing Record 16 of Set 1 | chuy
# Processing Record 17 of Set 1 | narsaq
# Processing Record 18 of Set 1 | vaini
# Processing Record 19 of Set 1 | port alfred
# Processing Record 20 of Set 1 | dikson
# Processing Record 21 of Set 1 | swakopmund
# Processing Record 22 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 23 of Set 1 | bintulu
# Processing Record 24 of Set 1 | arraial do cabo
# Processing Record 25 of Set 1 | skegness
# Processing Record 26 of Set 1 | longyearbyen
# Processing Record 27 of Set 1 | zhigansk
# Processing Record 28 of Set 1 | avarua
# Processing Record 29 of Set 1 | bredasdorp
# Processing Record 30 of Set 1 | makat
# Processing Record 31 of Set 1 | barrow
# Processing Record 32 of Set 1 | atuona
# Processing Record 33 of Set 1 | victoria
# Processing Record 34 of Set 1 | butaritari
# Processing Record 35 of Set 1 | north bend
# Processing Record 36 of Set 1 | saskylakh
# Processing Record 37 of Set 1 | severo-kurilsk
# Processing Record 38 of Set 1 | busselton
# Processing Record 39 of Set 1 | cherskiy
# Processing Record 40 of Set 1 | puerto narino
# Processing Record 41 of Set 1 | nanortalik
# Processing Record 42 of Set 1 | rikitea
# Processing Record 43 of Set 1 | fortuna
# Processing Record 44 of Set 1 | santa maria
# Processing Record 45 of Set 1 | rovaniemi
# Processing Record 46 of Set 1 | neka
# Processing Record 47 of Set 1 | san policarpo
# Processing Record 48 of Set 1 | ponta do sol
# Processing Record 49 of Set 1 | pacific grove
# Processing Record 50 of Set 1 | khatanga
# Processing Record 1 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 2 of Set 2 | tabuk
# Processing Record 3 of Set 2 | korla
# Processing Record 4 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 5 of Set 2 | halalo
# City not found. Skipping...
# Processing Record 6 of Set 2 | ushuaia
# Processing Record 7 of Set 2 | hermanus
# Processing Record 8 of Set 2 | cape town
# Processing Record 9 of Set 2 | pemba
# Processing Record 10 of Set 2 | bambous virieux
# Processing Record 11 of Set 2 | isangel
# Processing Record 12 of Set 2 | walvis bay
# Processing Record 13 of Set 2 | dingle
# Processing Record 14 of Set 2 | bundaberg
# Processing Record 15 of Set 2 | tiksi
# Processing Record 16 of Set 2 | rapid valley
# Processing Record 17 of Set 2 | port elizabeth
# Processing Record 18 of Set 2 | saint-augustin
# Processing Record 19 of Set 2 | presidencia roque saenz pena
# Processing Record 20 of Set 2 | seoul
# Processing Record 21 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 22 of Set 2 | palasa
# Processing Record 23 of Set 2 | shache
# Processing Record 24 of Set 2 | nonthaburi
# Processing Record 25 of Set 2 | thompson
# Processing Record 26 of Set 2 | hobart
# Processing Record 27 of Set 2 | fonte boa
# Processing Record 28 of Set 2 | ende
# Processing Record 29 of Set 2 | castro
# Processing Record 30 of Set 2 | tuatapere
# Processing Record 31 of Set 2 | east london
# Processing Record 32 of Set 2 | bahar
# Processing Record 33 of Set 2 | codrington
# Processing Record 34 of Set 2 | gusau
# Processing Record 35 of Set 2 | maracai
# Processing Record 36 of Set 2 | mar del plata
# Processing Record 37 of Set 2 | chiman
# Processing Record 38 of Set 2 | bluff
# Processing Record 39 of Set 2 | kazalinsk
# City not found. Skipping...
# Processing Record 40 of Set 2 | namibe
# Processing Record 41 of Set 2 | oistins
# Processing Record 42 of Set 2 | sept-iles
# Processing Record 43 of Set 2 | guerrero negro
# Processing Record 44 of Set 2 | saint-francois
# Processing Record 45 of Set 2 | yellowknife
# Processing Record 46 of Set 2 | cayenne
# Processing Record 47 of Set 2 | porto santo
# Processing Record 48 of Set 2 | ola
# Processing Record 49 of Set 2 | salina cruz
# Processing Record 50 of Set 2 | puerto ayora
# Processing Record 1 of Set 3 | port blair
# Processing Record 2 of Set 3 | jabiru
# City not found. Skipping...
# Processing Record 3 of Set 3 | zyryanka
# Processing Record 4 of Set 3 | alta floresta
# Processing Record 5 of Set 3 | chicama
# Processing Record 6 of Set 3 | tasiilaq
# Processing Record 7 of Set 3 | nsukka
# Processing Record 8 of Set 3 | yangliuqing
# Processing Record 9 of Set 3 | comodoro rivadavia
# Processing Record 10 of Set 3 | cienaga de flores
# City not found. Skipping...
# Processing Record 11 of Set 3 | sao joao da barra
# Processing Record 12 of Set 3 | praia
# Processing Record 13 of Set 3 | westport
# Processing Record 14 of Set 3 | goderich
# Processing Record 15 of Set 3 | suoyarvi
# Processing Record 16 of Set 3 | georgetown
# Processing Record 17 of Set 3 | mahebourg
# Processing Record 18 of Set 3 | dubuque
# Processing Record 19 of Set 3 | rawson
# Processing Record 20 of Set 3 | cabo san lucas
# Processing Record 21 of Set 3 | vao
# Processing Record 22 of Set 3 | ballarat
# Processing Record 23 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 24 of Set 3 | faanui
# Processing Record 25 of Set 3 | vestmanna
# Processing Record 26 of Set 3 | norman wells
# Processing Record 27 of Set 3 | kaitangata
# Processing Record 28 of Set 3 | naryan-mar
# Processing Record 29 of Set 3 | talnakh
# Processing Record 30 of Set 3 | tanout
# Processing Record 31 of Set 3 | provideniya
# Processing Record 32 of Set 3 | havelock
# Processing Record 33 of Set 3 | qabis
# City not found. Skipping...
# Processing Record 34 of Set 3 | amahai
# Processing Record 35 of Set 3 | birao
# Processing Record 36 of Set 3 | christchurch
# Processing Record 37 of Set 3 | ribeira grande
# Processing Record 38 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 39 of Set 3 | grenville
# Processing Record 40 of Set 3 | hsintien
# City not found. Skipping...
# Processing Record 41 of Set 3 | luderitz
# Processing Record 42 of Set 3 | xinqing
# Processing Record 43 of Set 3 | neyshabur
# Processing Record 44 of Set 3 | gari
# Processing Record 45 of Set 3 | belaya gora
# Processing Record 46 of Set 3 | warburg
# Processing Record 47 of Set 3 | kahului
# Processing Record 48 of Set 3 | egvekinot
# Processing Record 49 of Set 3 | labrea
# Processing Record 50 of Set 3 | megion
# Processing Record 1 of Set 4 | geraldton
# Processing Record 2 of Set 4 | kodiak
# Processing Record 3 of Set 4 | qujing
# Processing Record 4 of Set 4 | maragogi
# Processing Record 5 of Set 4 | tulagi
# Processing Record 6 of Set 4 | mbamba
# Processing Record 7 of Set 4 | harper
# Processing Record 8 of Set 4 | hithadhoo
# Processing Record 9 of Set 4 | maur
# Processing Record 10 of Set 4 | hilo
# Processing Record 11 of Set 4 | torbay
# Processing Record 12 of Set 4 | itarema
# Processing Record 13 of Set 4 | talara
# Processing Record 14 of Set 4 | mahon
# Processing Record 15 of Set 4 | saint george
# Processing Record 16 of Set 4 | mackay
# Processing Record 17 of Set 4 | boyolangu
# Processing Record 18 of Set 4 | tatarsk
# Processing Record 19 of Set 4 | cockburn town
# Processing Record 20 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 21 of Set 4 | sorong
# Processing Record 22 of Set 4 | bethel
# Processing Record 23 of Set 4 | plettenberg bay
# Processing Record 24 of Set 4 | vila velha
# Processing Record 25 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 26 of Set 4 | fort nelson
# Processing Record 27 of Set 4 | qui nhon
# Processing Record 28 of Set 4 | redlands
# Processing Record 29 of Set 4 | tessalit
# Processing Record 30 of Set 4 | samsun
# Processing Record 31 of Set 4 | rocha
# Processing Record 32 of Set 4 | nikolskoye
# Processing Record 33 of Set 4 | bousse
# Processing Record 34 of Set 4 | belyy yar
# Processing Record 35 of Set 4 | taywarah
# Processing Record 36 of Set 4 | altagracia de orituco
# Processing Record 37 of Set 4 | kavieng
# Processing Record 38 of Set 4 | aflu
# City not found. Skipping...
# Processing Record 39 of Set 4 | los llanos de aridane
# Processing Record 40 of Set 4 | qaanaaq
# Processing Record 41 of Set 4 | yulara
# Processing Record 42 of Set 4 | oktyabrskiy
# Processing Record 43 of Set 4 | sehnde
# Processing Record 44 of Set 4 | groton
# Processing Record 45 of Set 4 | vostok
# Processing Record 46 of Set 4 | taft
# Processing Record 47 of Set 4 | esso
# Processing Record 48 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 49 of Set 4 | vagur
# Processing Record 50 of Set 4 | lebu
# Processing Record 1 of Set 5 | lompoc
# Processing Record 2 of Set 5 | gat
# Processing Record 3 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 4 of Set 5 | stornoway
# Processing Record 5 of Set 5 | marolambo
# Processing Record 6 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 7 of Set 5 | kumhari
# Processing Record 8 of Set 5 | nouadhibou
# Processing Record 9 of Set 5 | aginskoye
# Processing Record 10 of Set 5 | fort saint john
# City not found. Skipping...
# Processing Record 11 of Set 5 | palmer
# Processing Record 12 of Set 5 | alice springs
# Processing Record 13 of Set 5 | kirov
# Processing Record 14 of Set 5 | mbulu
# Processing Record 15 of Set 5 | rincon
# Processing Record 16 of Set 5 | reinosa
# Processing Record 17 of Set 5 | eureka
# Processing Record 18 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 19 of Set 5 | kuching
# Processing Record 20 of Set 5 | ocos
# Processing Record 21 of Set 5 | clyde river
# Processing Record 22 of Set 5 | airai
# Processing Record 23 of Set 5 | belen
# Processing Record 24 of Set 5 | aktash
# Processing Record 25 of Set 5 | san quintin
# Processing Record 26 of Set 5 | urucara
# Processing Record 27 of Set 5 | lawton
# Processing Record 28 of Set 5 | boueni
# Processing Record 29 of Set 5 | necochea
# Processing Record 30 of Set 5 | cidreira
# Processing Record 31 of Set 5 | berlevag
# Processing Record 32 of Set 5 | visnes
# Processing Record 33 of Set 5 | yaan
# Processing Record 34 of Set 5 | saldanha
# Processing Record 35 of Set 5 | ciudad dario
# Processing Record 36 of Set 5 | ryotsu
# Processing Record 37 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 38 of Set 5 | ferrol
# Processing Record 39 of Set 5 | rafaela
# Processing Record 40 of Set 5 | rudnyy
# Processing Record 41 of Set 5 | san cristobal
# Processing Record 42 of Set 5 | shellbrook
# Processing Record 43 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 44 of Set 5 | port lincoln
# Processing Record 45 of Set 5 | krasnoselkup
# Processing Record 46 of Set 5 | susangerd
# Processing Record 47 of Set 5 | wahpeton
# Processing Record 48 of Set 5 | hualmay
# Processing Record 49 of Set 5 | olafsvik
# Processing Record 50 of Set 5 | matara
# Processing Record 1 of Set 6 | kamaishi
# Processing Record 2 of Set 6 | katsuura
# Processing Record 3 of Set 6 | yaring
# Processing Record 4 of Set 6 | susurluk
# Processing Record 5 of Set 6 | lubumbashi
# Processing Record 6 of Set 6 | san jose iturbide
# Processing Record 7 of Set 6 | hami
# Processing Record 8 of Set 6 | salalah
# Processing Record 9 of Set 6 | ayorou
# Processing Record 10 of Set 6 | new norfolk
# Processing Record 11 of Set 6 | barbar
# City not found. Skipping...
# Processing Record 12 of Set 6 | avera
# Processing Record 13 of Set 6 | ocean city
# Processing Record 14 of Set 6 | tual
# Processing Record 15 of Set 6 | awjilah
# Processing Record 16 of Set 6 | paucartambo
# City not found. Skipping...
# Processing Record 17 of Set 6 | camalu
# Processing Record 18 of Set 6 | kuytun
# Processing Record 19 of Set 6 | elizabeth city
# Processing Record 20 of Set 6 | murray bridge
# Processing Record 21 of Set 6 | tuktoyaktuk
# Processing Record 22 of Set 6 | batemans bay
# Processing Record 23 of Set 6 | oranjemund
# Processing Record 24 of Set 6 | radviliskis
# Processing Record 25 of Set 6 | vestmannaeyjar
# Processing Record 26 of Set 6 | iqaluit
# Processing Record 27 of Set 6 | poum
# Processing Record 28 of Set 6 | hambantota
# Processing Record 29 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 30 of Set 6 | carnarvon
# Processing Record 31 of Set 6 | vardo
# Processing Record 32 of Set 6 | bengkulu
# Processing Record 33 of Set 6 | bababe
# City not found. Skipping...
# Processing Record 34 of Set 6 | steinbach
# Processing Record 35 of Set 6 | libreville
# Processing Record 36 of Set 6 | mahadday weyne
# City not found. Skipping...
# Processing Record 37 of Set 6 | springbok
# Processing Record 38 of Set 6 | doha
# Processing Record 39 of Set 6 | shatsk
# Processing Record 40 of Set 6 | kudahuvadhoo
# Processing Record 41 of Set 6 | kyshtovka
# Processing Record 42 of Set 6 | gravdal
# Processing Record 43 of Set 6 | te horo
# Processing Record 44 of Set 6 | ixtapa
# Processing Record 45 of Set 6 | qaqortoq
# Processing Record 46 of Set 6 | chimoio
# Processing Record 47 of Set 6 | richards bay
# Processing Record 48 of Set 6 | rabak
# Processing Record 49 of Set 6 | wloszczowa
# Processing Record 50 of Set 6 | puerto escondido
# Processing Record 1 of Set 7 | lutz
# Processing Record 2 of Set 7 | riyadh
# Processing Record 3 of Set 7 | demyansk
# Processing Record 4 of Set 7 | boguchany
# Processing Record 5 of Set 7 | mogadishu
# Processing Record 6 of Set 7 | lashio
# Processing Record 7 of Set 7 | souillac
# Processing Record 8 of Set 7 | gwadar
# Processing Record 9 of Set 7 | dunedin
# Processing Record 10 of Set 7 | hamilton
# Processing Record 11 of Set 7 | mount isa
# Processing Record 12 of Set 7 | mehamn
# Processing Record 13 of Set 7 | porto novo
# Processing Record 14 of Set 7 | narasannapeta
# Processing Record 15 of Set 7 | yar-sale
# Processing Record 16 of Set 7 | esperance
# Processing Record 17 of Set 7 | dibaya
# City not found. Skipping...
# Processing Record 18 of Set 7 | gander
# Processing Record 19 of Set 7 | husavik
# Processing Record 20 of Set 7 | derzhavinsk
# Processing Record 21 of Set 7 | olginskaya
# Processing Record 22 of Set 7 | kopargaon
# Processing Record 23 of Set 7 | ilmajoki
# Processing Record 24 of Set 7 | bitung
# Processing Record 25 of Set 7 | opoczno
# Processing Record 26 of Set 7 | ilulissat
# Processing Record 27 of Set 7 | komsomolskiy
# Processing Record 28 of Set 7 | port macquarie
# Processing Record 29 of Set 7 | mount gambier
# Processing Record 30 of Set 7 | beringovskiy
# Processing Record 31 of Set 7 | niquero
# Processing Record 32 of Set 7 | la trinitaria
# Processing Record 33 of Set 7 | sarahan
# Processing Record 34 of Set 7 | san marzano sul sarno
# Processing Record 35 of Set 7 | cochrane
# Processing Record 36 of Set 7 | fatehpur
# Processing Record 37 of Set 7 | paamiut
# Processing Record 38 of Set 7 | dryden
# Processing Record 39 of Set 7 | san patricio
# Processing Record 40 of Set 7 | kelo
# Processing Record 41 of Set 7 | lakes entrance
# Processing Record 42 of Set 7 | staritsa
# Processing Record 43 of Set 7 | nago
# Processing Record 44 of Set 7 | changji
# Processing Record 45 of Set 7 | pisco
# Processing Record 46 of Set 7 | griffith
# Processing Record 47 of Set 7 | tautira
# Processing Record 48 of Set 7 | meadow lake
# Processing Record 49 of Set 7 | taoudenni
# Processing Record 50 of Set 7 | skjervoy
# Processing Record 1 of Set 8 | cozumel
# Processing Record 2 of Set 8 | havoysund
# Processing Record 3 of Set 8 | champerico
# Processing Record 4 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 5 of Set 8 | beyneu
# Processing Record 6 of Set 8 | ahipara
# Processing Record 7 of Set 8 | tefe
# Processing Record 8 of Set 8 | manokwari
# Processing Record 9 of Set 8 | byron bay
# Processing Record 10 of Set 8 | tahe
# Processing Record 11 of Set 8 | swansea
# Processing Record 12 of Set 8 | hay river
# Processing Record 13 of Set 8 | matay
# Processing Record 14 of Set 8 | sena madureira
# Processing Record 15 of Set 8 | arlit
# Processing Record 16 of Set 8 | sao filipe
# Processing Record 17 of Set 8 | jieshi
# Processing Record 18 of Set 8 | uwayl
# City not found. Skipping...
# Processing Record 19 of Set 8 | dwarka
# Processing Record 20 of Set 8 | grand-santi
# Processing Record 21 of Set 8 | itupiranga
# Processing Record 22 of Set 8 | santa cruz
# Processing Record 23 of Set 8 | kirkenaer
# Processing Record 24 of Set 8 | altay
# Processing Record 25 of Set 8 | nishihara
# Processing Record 26 of Set 8 | noumea
# Processing Record 27 of Set 8 | galveston
# Processing Record 28 of Set 8 | jalu
# Processing Record 29 of Set 8 | chokurdakh
# Processing Record 30 of Set 8 | wiarton
# Processing Record 31 of Set 8 | hurghada
# Processing Record 32 of Set 8 | zhemchuzhnyy
# City not found. Skipping...
# Processing Record 33 of Set 8 | sao felix do xingu
# Processing Record 34 of Set 8 | coahuayana
# Processing Record 35 of Set 8 | barra do garcas
# Processing Record 36 of Set 8 | kutum
# Processing Record 37 of Set 8 | oyama
# Processing Record 38 of Set 8 | maldonado
# Processing Record 39 of Set 8 | kawambwa
# Processing Record 40 of Set 8 | salekhard
# Processing Record 41 of Set 8 | quatre cocos
# Processing Record 42 of Set 8 | nome
# Processing Record 43 of Set 8 | unidos
# Processing Record 44 of Set 8 | sorland
# Processing Record 45 of Set 8 | upernavik
# Processing Record 46 of Set 8 | grindavik
# Processing Record 47 of Set 8 | kamenka
# Processing Record 48 of Set 8 | lorengau
# Processing Record 49 of Set 8 | freital
# Processing Record 50 of Set 8 | bilma
# Processing Record 1 of Set 9 | hanzhong
# Processing Record 2 of Set 9 | taunggyi
# Processing Record 3 of Set 9 | kruisfontein
# Processing Record 4 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 5 of Set 9 | havre-saint-pierre
# Processing Record 6 of Set 9 | mehran
# Processing Record 7 of Set 9 | hofn
# Processing Record 8 of Set 9 | tigil
# Processing Record 9 of Set 9 | amnat charoen
# Processing Record 10 of Set 9 | verkhnevilyuysk
# Processing Record 11 of Set 9 | bur gabo
# City not found. Skipping...
# Processing Record 12 of Set 9 | balugo
# Processing Record 13 of Set 9 | skelleftea
# Processing Record 14 of Set 9 | buraydah
# Processing Record 15 of Set 9 | wukari
# Processing Record 16 of Set 9 | ambunti
# Processing Record 17 of Set 9 | karratha
# Processing Record 18 of Set 9 | araouane
# Processing Record 19 of Set 9 | sibolga
# Processing Record 20 of Set 9 | port augusta
# Processing Record 21 of Set 9 | pavilosta
# Processing Record 22 of Set 9 | kandrian
# Processing Record 23 of Set 9 | cedar city
# Processing Record 24 of Set 9 | zhanakorgan
# Processing Record 25 of Set 9 | bilibino
# Processing Record 26 of Set 9 | tucupita
# Processing Record 27 of Set 9 | belmonte
# Processing Record 28 of Set 9 | tralee
# Processing Record 29 of Set 9 | fayaoue
# Processing Record 30 of Set 9 | mabaruma
# Processing Record 31 of Set 9 | wyndham
# Processing Record 32 of Set 9 | pochutla
# Processing Record 33 of Set 9 | miram shah
# Processing Record 34 of Set 9 | sobolevo
# Processing Record 35 of Set 9 | port hedland
# Processing Record 36 of Set 9 | leningradskiy
# Processing Record 37 of Set 9 | asau
# Processing Record 38 of Set 9 | darab
# Processing Record 39 of Set 9 | pangnirtung
# Processing Record 40 of Set 9 | nantucket
# Processing Record 41 of Set 9 | amuntai
# Processing Record 42 of Set 9 | yeppoon
# Processing Record 43 of Set 9 | bereda
# Processing Record 44 of Set 9 | angra dos reis
# Processing Record 45 of Set 9 | san jose
# Processing Record 46 of Set 9 | santana do paraiso
# Processing Record 47 of Set 9 | pundaguitan
# Processing Record 48 of Set 9 | abu samrah
# Processing Record 49 of Set 9 | bajil
# Processing Record 50 of Set 9 | sitio novo do tocantins
# Processing Record 1 of Set 10 | bentiu
# Processing Record 2 of Set 10 | peniche
# Processing Record 3 of Set 10 | high level
# Processing Record 4 of Set 10 | zemio
# Processing Record 5 of Set 10 | requena
# Processing Record 6 of Set 10 | portland
# Processing Record 7 of Set 10 | ancud
# Processing Record 8 of Set 10 | san luis
# Processing Record 9 of Set 10 | anloga
# Processing Record 10 of Set 10 | anito
# Processing Record 11 of Set 10 | tarauaca
# Processing Record 12 of Set 10 | aksarka
# Processing Record 13 of Set 10 | quang ngai
# Processing Record 14 of Set 10 | sabzevar
# Processing Record 15 of Set 10 | satitoa
# City not found. Skipping...
# Processing Record 16 of Set 10 | lucea
# Processing Record 17 of Set 10 | lethem
# Processing Record 18 of Set 10 | nata
# Processing Record 19 of Set 10 | ambon
# Processing Record 20 of Set 10 | kawana waters
# City not found. Skipping...
# Processing Record 21 of Set 10 | soe
# Processing Record 22 of Set 10 | halden
# Processing Record 23 of Set 10 | sonoita
# Processing Record 24 of Set 10 | linguere
# Processing Record 25 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 26 of Set 10 | port moresby
# Processing Record 27 of Set 10 | constitucion
# Processing Record 28 of Set 10 | bagdarin
# Processing Record 29 of Set 10 | northam
# Processing Record 30 of Set 10 | el alto
# Processing Record 31 of Set 10 | maumere
# Processing Record 32 of Set 10 | saint-georges
# Processing Record 33 of Set 10 | chivay
# Processing Record 34 of Set 10 | nemuro
# Processing Record 35 of Set 10 | bethanien
# Processing Record 36 of Set 10 | berdigestyakh
# Processing Record 37 of Set 10 | tyrma
# Processing Record 38 of Set 10 | tongchuan
# Processing Record 39 of Set 10 | rosita
# Processing Record 40 of Set 10 | manggar
# Processing Record 41 of Set 10 | vila franca do campo
# Processing Record 42 of Set 10 | kholtoson
# Processing Record 43 of Set 10 | malatya
# Processing Record 44 of Set 10 | ajdabiya
# Processing Record 45 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 46 of Set 10 | bay roberts
# Processing Record 47 of Set 10 | touros
# Processing Record 48 of Set 10 | adrar
# Processing Record 49 of Set 10 | rio claro
# Processing Record 50 of Set 10 | lichinga
# Processing Record 1 of Set 11 | rabat
# Processing Record 2 of Set 11 | lavrentiya
# Processing Record 3 of Set 11 | qarqin
# Processing Record 4 of Set 11 | iralaya
# Processing Record 5 of Set 11 | heihe
# Processing Record 6 of Set 11 | baykit
# Processing Record 7 of Set 11 | marrakesh
# Processing Record 8 of Set 11 | kaeo
# Processing Record 9 of Set 11 | ginda
# Processing Record 10 of Set 11 | hasaki
# Processing Record 11 of Set 11 | kjustendil
# Processing Record 12 of Set 11 | brae
# Processing Record 13 of Set 11 | gigmoto
# Processing Record 14 of Set 11 | thaba-tseka
# Processing Record 15 of Set 11 | carman
# Processing Record 16 of Set 11 | makubetsu
# Processing Record 17 of Set 11 | teknaf
# Processing Record 18 of Set 11 | waingapu
# Processing Record 19 of Set 11 | buchanan
# Processing Record 20 of Set 11 | marawi
# Processing Record 21 of Set 11 | panguiranan
# Processing Record 22 of Set 11 | igrim
# Processing Record 23 of Set 11 | bela vista
# Processing Record 24 of Set 11 | alofi
# Processing Record 25 of Set 11 | rostaq
# City not found. Skipping...
# Processing Record 26 of Set 11 | surab
# Processing Record 27 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 28 of Set 11 | beaverlodge
# Processing Record 29 of Set 11 | rio gallegos
# Processing Record 30 of Set 11 | half moon bay
# Processing Record 31 of Set 11 | te anau
# Processing Record 32 of Set 11 | wakkanai
# Processing Record 33 of Set 11 | dongsheng
# Processing Record 34 of Set 11 | kalmunai
# Processing Record 35 of Set 11 | otradnoye
# Processing Record 36 of Set 11 | barranca
# Processing Record 37 of Set 11 | keflavik
# Processing Record 38 of Set 11 | tombouctou
# Processing Record 39 of Set 11 | ulladulla
# Processing Record 40 of Set 11 | viedma
# Processing Record 41 of Set 11 | jurm
# Processing Record 42 of Set 11 | las palmas
# Processing Record 43 of Set 11 | mantua
# Processing Record 44 of Set 11 | mangalam
# Processing Record 45 of Set 11 | biscarrosse
# Processing Record 46 of Set 11 | daxian
# City not found. Skipping...
# Processing Record 47 of Set 11 | sakakah
# Processing Record 48 of Set 11 | luganville
# Processing Record 49 of Set 11 | burkhala
# City not found. Skipping...
# Processing Record 50 of Set 11 | naze
# Processing Record 1 of Set 12 | ulaangom
# Processing Record 2 of Set 12 | marzuq
# Processing Record 3 of Set 12 | shenjiamen
# Processing Record 4 of Set 12 | bathsheba
# Processing Record 5 of Set 12 | xichang
# Processing Record 6 of Set 12 | la rioja
# Processing Record 7 of Set 12 | dudinka
# Processing Record 8 of Set 12 | mayumba
# Processing Record 9 of Set 12 | port hawkesbury
# Processing Record 10 of Set 12 | huai yot
# Processing Record 11 of Set 12 | shu
# Processing Record 12 of Set 12 | tadine
# Processing Record 13 of Set 12 | mentougou
# Processing Record 14 of Set 12 | sretensk
# Processing Record 15 of Set 12 | kismayo
# Processing Record 16 of Set 12 | saint anthony
# Processing Record 17 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 18 of Set 12 | roma
# Processing Record 19 of Set 12 | tabialan
# City not found. Skipping...
# Processing Record 20 of Set 12 | tchibanga
# Processing Record 21 of Set 12 | inta
# Processing Record 22 of Set 12 | mikhaylovka
# Processing Record 23 of Set 12 | sitka
# Processing Record 24 of Set 12 | limbe
# Processing Record 25 of Set 12 | aklavik
# Processing Record 26 of Set 12 | shingu
# Processing Record 27 of Set 12 | burnie
# Processing Record 28 of Set 12 | akropong
# Processing Record 29 of Set 12 | roald
# Processing Record 30 of Set 12 | athens
# Processing Record 31 of Set 12 | ponta delgada
# Processing Record 32 of Set 12 | rio tercero
# Processing Record 33 of Set 12 | tilichiki
# Processing Record 34 of Set 12 | pitimbu
# Processing Record 35 of Set 12 | la asuncion
# Processing Record 36 of Set 12 | phan rang
# City not found. Skipping...
# Processing Record 37 of Set 12 | sambava
# Processing Record 38 of Set 12 | nebolchi
# Processing Record 39 of Set 12 | luce
# Processing Record 40 of Set 12 | superior
# Processing Record 41 of Set 12 | wiang sa
# Processing Record 42 of Set 12 | san lorenzo
# Processing Record 43 of Set 12 | uvat
# Processing Record 44 of Set 12 | tateyama
# Processing Record 45 of Set 12 | centralia
# Processing Record 46 of Set 12 | khonuu
# City not found. Skipping...
# Processing Record 47 of Set 12 | yilan
# Processing Record 48 of Set 12 | mangrol
# Processing Record 49 of Set 12 | smithers
# Processing Record 50 of Set 12 | young
# Processing Record 1 of Set 13 | ranong
# Processing Record 2 of Set 13 | sur
# Processing Record 3 of Set 13 | saint-pierre
# Processing Record 4 of Set 13 | utrecht
# Processing Record 5 of Set 13 | kainantu
# Processing Record 6 of Set 13 | kalabo
# Processing Record 7 of Set 13 | aljezur
# Processing Record 8 of Set 13 | mitsamiouli
# Processing Record 9 of Set 13 | lumphat
# Processing Record 10 of Set 13 | buenos aires
# Processing Record 11 of Set 13 | wattegama
# Processing Record 12 of Set 13 | jinka
# Processing Record 13 of Set 13 | acari
# Processing Record 14 of Set 13 | camden
# Processing Record 15 of Set 13 | iranshahr
# Processing Record 16 of Set 13 | cadillac
# Processing Record 17 of Set 13 | luwuk
# Processing Record 18 of Set 13 | machinga
# Processing Record 19 of Set 13 | siay
# Processing Record 20 of Set 13 | kongoussi
# Processing Record 21 of Set 13 | lata
# Processing Record 22 of Set 13 | ust-omchug
# Processing Record 23 of Set 13 | altus
# Processing Record 24 of Set 13 | conde
# Processing Record 25 of Set 13 | san andres
# Processing Record 26 of Set 13 | kurtamysh
# Processing Record 27 of Set 13 | tikapur
# Processing Record 28 of Set 13 | marienburg
# Processing Record 29 of Set 13 | vanimo
# Processing Record 30 of Set 13 | batticaloa
# Processing Record 31 of Set 13 | camapua
# Processing Record 32 of Set 13 | eyemouth
# Processing Record 33 of Set 13 | betanzos
# Processing Record 34 of Set 13 | hobyo
# Processing Record 35 of Set 13 | mpika
# Processing Record 36 of Set 13 | kalat
# Processing Record 37 of Set 13 | wanning
# Processing Record 38 of Set 13 | wladyslawowo
# Processing Record 39 of Set 13 | meridian
# Processing Record 40 of Set 13 | buala
# Processing Record 41 of Set 13 | marsabit
# Processing Record 42 of Set 13 | gizo
# Processing Record 43 of Set 13 | banda aceh
# Processing Record 44 of Set 13 | konosha
# Processing Record 45 of Set 13 | ostrovnoy
# Processing Record 46 of Set 13 | tarko-sale
# Processing Record 47 of Set 13 | basoko
# Processing Record 48 of Set 13 | inhambane
# Processing Record 49 of Set 13 | lokosovo
# Processing Record 50 of Set 13 | labuan
# Processing Record 1 of Set 14 | dicabisagan
# Processing Record 2 of Set 14 | hammerfest
# Processing Record 3 of Set 14 | zelenogorskiy
# Processing Record 4 of Set 14 | duz
# City not found. Skipping...
# Processing Record 5 of Set 14 | armeria
# Processing Record 6 of Set 14 | broome
# Processing Record 7 of Set 14 | neustadt
# Processing Record 8 of Set 14 | madisonville
# Processing Record 9 of Set 14 | mergui
# City not found. Skipping...
# Processing Record 10 of Set 14 | verkhoyansk
# Processing Record 11 of Set 14 | ruatoria
# City not found. Skipping...
# Processing Record 12 of Set 14 | kimbe
# Processing Record 13 of Set 14 | salinopolis
# Processing Record 14 of Set 14 | quelimane
# Processing Record 15 of Set 14 | metehara
# City not found. Skipping...
# Processing Record 16 of Set 14 | great yarmouth
# Processing Record 17 of Set 14 | channel-port aux basques
# Processing Record 18 of Set 14 | karuzi
# Processing Record 19 of Set 14 | auki
# Processing Record 20 of Set 14 | ornskoldsvik
# Processing Record 21 of Set 14 | morant bay
# Processing Record 22 of Set 14 | winnemucca
# Processing Record 23 of Set 14 | bingol
# Processing Record 24 of Set 14 | ginir
# Processing Record 25 of Set 14 | bubaque
# Processing Record 26 of Set 14 | kenai
# Processing Record 27 of Set 14 | fuerte olimpo
# Processing Record 28 of Set 14 | samthar
# Processing Record 29 of Set 14 | hit
# Processing Record 30 of Set 14 | honiara
# Processing Record 31 of Set 14 | huarmey
# Processing Record 32 of Set 14 | arroio grande
# Processing Record 33 of Set 14 | ormond beach
# Processing Record 34 of Set 14 | halifax
# Processing Record 35 of Set 14 | labuhan
# Processing Record 36 of Set 14 | sovetskaya gavan
# Processing Record 37 of Set 14 | mango
# Processing Record 38 of Set 14 | jinji
# Processing Record 39 of Set 14 | tigzirt
# Processing Record 40 of Set 14 | wanxian
# Processing Record 41 of Set 14 | wasilla
# Processing Record 42 of Set 14 | la reforma
# Processing Record 43 of Set 14 | turukhansk
# Processing Record 44 of Set 14 | jubayl
# City not found. Skipping...
# Processing Record 45 of Set 14 | iskateley
# Processing Record 46 of Set 14 | owando
# Processing Record 47 of Set 14 | fereydun kenar
# Processing Record 48 of Set 14 | pasighat
# Processing Record 49 of Set 14 | karaul
# City not found. Skipping...
# Processing Record 50 of Set 14 | gavle
# Processing Record 1 of Set 15 | malanje
# Processing Record 2 of Set 15 | oleksandrivka
# Processing Record 3 of Set 15 | mbarara
# Processing Record 4 of Set 15 | nyurba
# Processing Record 5 of Set 15 | sri aman
# Processing Record 6 of Set 15 | inderborskiy
# City not found. Skipping...
# Processing Record 7 of Set 15 | panama city
# Processing Record 8 of Set 15 | aripuana
# Processing Record 9 of Set 15 | katherine
# Processing Record 10 of Set 15 | nara
# Processing Record 11 of Set 15 | montgomery
# Processing Record 12 of Set 15 | makung
# City not found. Skipping...
# Processing Record 13 of Set 15 | kurilsk
# Processing Record 14 of Set 15 | suluq
# Processing Record 15 of Set 15 | khani
# Processing Record 16 of Set 15 | vizinga
# Processing Record 17 of Set 15 | tahoua
# Processing Record 18 of Set 15 | suba
# Processing Record 19 of Set 15 | tarakan
# Processing Record 20 of Set 15 | taraz
# Processing Record 21 of Set 15 | yenagoa
# Processing Record 22 of Set 15 | kortkeros
# Processing Record 23 of Set 15 | bud
# Processing Record 24 of Set 15 | ugra
# Processing Record 25 of Set 15 | kanadukathan
# Processing Record 26 of Set 15 | mayo
# Processing Record 27 of Set 15 | bosaso
# Processing Record 28 of Set 15 | inverell
# Processing Record 29 of Set 15 | zapolyarnyy
# Processing Record 30 of Set 15 | saint marys
# Processing Record 31 of Set 15 | abu zabad
# Processing Record 32 of Set 15 | coquimbo
# Processing Record 33 of Set 15 | kidal
# Processing Record 34 of Set 15 | revelstoke
# Processing Record 35 of Set 15 | muisne
# Processing Record 36 of Set 15 | yerbogachen
# Processing Record 37 of Set 15 | wulanhaote
# City not found. Skipping...
# Processing Record 38 of Set 15 | tromso
# Processing Record 39 of Set 15 | itoman
# Processing Record 40 of Set 15 | whitehorse
# Processing Record 41 of Set 15 | abay
# Processing Record 42 of Set 15 | la ronge
# Processing Record 43 of Set 15 | novobelokatay
# Processing Record 44 of Set 15 | ariano irpino
# Processing Record 45 of Set 15 | chateau-thierry
# Processing Record 46 of Set 15 | samdari
# Processing Record 47 of Set 15 | yumen
# Processing Record 48 of Set 15 | parintins
# Processing Record 49 of Set 15 | hunza
# City not found. Skipping...
# Processing Record 50 of Set 15 | porto walter
# Processing Record 1 of Set 16 | ngukurr
# City not found. Skipping...
# Processing Record 2 of Set 16 | hovd
# Processing Record 3 of Set 16 | padang
# Processing Record 4 of Set 16 | fare
# Processing Record 5 of Set 16 | buin
# Processing Record 6 of Set 16 | bogovarovo
# Processing Record 7 of Set 16 | qasigiannguit
# Processing Record 8 of Set 16 | ostersund
# Processing Record 9 of Set 16 | oussouye
# Processing Record 10 of Set 16 | mnogovershinnyy
# Processing Record 11 of Set 16 | todos santos
# Processing Record 12 of Set 16 | bury saint edmunds
# City not found. Skipping...
# Processing Record 13 of Set 16 | camabatela
# Processing Record 14 of Set 16 | port-cartier
# Processing Record 15 of Set 16 | kharp
# Processing Record 16 of Set 16 | chaiya
# Processing Record 17 of Set 16 | bulawayo
# Processing Record 18 of Set 16 | alihe
# Processing Record 19 of Set 16 | rudraprayag
# Processing Record 20 of Set 16 | kavaratti
# Processing Record 21 of Set 16 | muroto
# Processing Record 22 of Set 16 | gibara
# Processing Record 23 of Set 16 | kollumerland
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 714

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity Current Description  \
# 0           Pevek  69.7008  170.3133     27.88        70       broken clouds
# 1         Mataura -46.1927  168.8643     40.48        95          light rain
# 2        Tomatlan  19.9333 -105.2500     73.45        95     overcast clouds
# 3       Caravelas -17.7125  -39.2481     73.96        82       broken clouds
# 4    Punta Arenas -53.1500  -70.9167     42.91        81       broken clouds
# 5           Kapaa  22.0752 -159.3190     82.38        75    scattered clouds
# 6  Saint-Philippe -21.3585   55.7679     76.59        72    scattered clouds
# 7           Kitui  -1.3670   38.0106     65.43        58           clear sky
# 8        Klaksvik  62.2266   -6.5890     49.12        84          light rain
# 9       Nandurbar  21.3667   74.2500     86.81        50    scattered clouds
#
#    Cloudiness  Wind Speed Country
# 0          76        4.83      RU
# 1          99       12.12      NZ
# 2          89        1.66      MX
# 3          60       10.04      BR
# 4          75       17.27      CL
# 5          40       13.80      US
# 6          40       11.32      RE
# 7           6        8.03      KE
# 8          14       34.69      FO
# 9          40       11.39      IN

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Current Description',
#        'Cloudiness', 'Wind Speed', 'Country'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
# YOUR CODE HERE
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed","Current Description"]
# Recreate the DataFrame by using the new column order
# YOUR CODE HERE
city_data_df= city_data_df[new_column_order]
# Display sample data
# YOUR CODE HERE
city_data_df
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Pevek      RU  69.7008  170.3133     27.88        70          76
# 1         Mataura      NZ -46.1927  168.8643     40.48        95          99
# 2        Tomatlan      MX  19.9333 -105.2500     73.45        95          89
# 3       Caravelas      BR -17.7125  -39.2481     73.96        82          60
# 4    Punta Arenas      CL -53.1500  -70.9167     42.91        81          75
# ..            ...     ...      ...       ...       ...       ...         ...
# 709         Alihe      CN  50.5667  123.7167     42.87        26          49
# 710   Rudraprayag      IN  30.2833   78.9833     81.72        61           8
# 711     Kavaratti      IN  10.5669   72.6420     81.46        77          72
# 712        Muroto      JP  33.2833  134.1500     74.55        73          96
# 713        Gibara      CU  21.1097  -76.1317     76.32        85          84
#
#      Wind Speed Current Description
# 0          4.83       broken clouds
# 1         12.12          light rain
# 2          1.66     overcast clouds
# 3         10.04       broken clouds
# 4         17.27       broken clouds
# ..          ...                 ...
# 709        9.26    scattered clouds
# 710        4.09           clear sky
# 711       13.24       broken clouds
# 712       14.50     overcast clouds
# 713        4.92       broken clouds
#
# [714 rows x 9 columns]

# %%
# Display the data types of each column by using the dtypes Pandas function
# YOUR CODE HERE
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
# YOUR CODE HERE
output_data_file = "WeatherPy_Database.csv"
# Export the city_data DataFrame into a CSV file
# YOUR CODE HERE
city_data_df.to_csv(output_data_file, index_label="City_ID")
